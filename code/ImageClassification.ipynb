# %%
import tensorflow as tf
import numpy as np
import os
from keras import datasets, layers, models
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

# %%
img = mpimg.imread(r'C:\DeepLearning\ImageClassification\data\dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (225, 300, 3)

# %%
print(img)
# Out:
# [[[167 133  62]
#   [167 133  62]
#   [168 134  64]
#   ...
#   [231 239 246]
#   [232 240 247]
#   [232 240 247]]
#
#  [[167 133  62]
#   [167 133  62]
#   [167 133  62]
#   ...
#   [231 239 246]
#   [232 240 247]
#   [232 240 247]]
#
#  [[167 133  62]
#   [167 133  62]
#   [166 132  61]
#   ...
#   [230 238 244]
#   [232 240 247]
#   [232 240 247]]
#
#  ...
#
#  [[157 147  57]
#   [162 151  62]
#   [170 160  70]
#   ...
#   [136 131  49]
#   [142 137  57]
#   [143 138  58]]
#
#  [[157 147  57]
#   [162 151  62]
#   [171 161  71]
#   ...
#   [141 136  53]
#   [147 142  61]
#   [150 145  65]]
#
#  [[156 148  57]
#   [162 153  63]
#   [170 162  71]
#   ...
#   [148 141  59]
#   [154 147  65]
#   [156 149  67]]]

# %%
img_plot = plt.imshow(img)

# %% [markdown]
# Resizing image using pillow Library

# %%
from PIL import Image
img = Image.open(r'C:\DeepLearning\ImageClassification\data\dog.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_resized.jpg')

# %%
img_res_plot = plt.imshow(img_resized)

# %%
img_res = mpimg.imread(r'C:\DeepLearning\ImageClassification\data\dog_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# Convert rgb image into greyscale using opencv

# %%
img = cv2.imread(r'C:\DeepLearning\ImageClassification\data\dog.jpg')

# %%
img.shape
# Out:
# (225, 300, 3)

# %%
greyscale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
type(greyscale_img)
# Out:
# numpy.ndarray

# %%
greyscale_img.shape
# Out:
# (225, 300)

# %%
img_res_plot = plt.imshow(greyscale_img)
plt.show()

# %%
cv2.imwrite('dog_greyscale.jpg',greyscale_img)
# Out:
# True
